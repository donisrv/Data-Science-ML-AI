# %% [markdown]
# <a href="https://colab.research.google.com/github/donisrv/Data-Science-ML-AI/blob/main/Indekslash_va_Kesish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><font face="Britannic, Arial" color=green >Data Science va Sun'iy Intellekt Praktikum </font></h1>
# <h2>Ma'lumotlar tahlili.</h2>
# 2.1. NumPy kutubxonasi bilan ishlash
# NumPy kutubxonasini chaqirib olish

# %%
import numpy as np

# %% [markdown]
# 2.1.1. N-o'lchamli massiv (array)larga ishlov berish
# Indeks va kesib olish asoslari

# %% [markdown]
# ![загруженное.png](data:image/png;base64,...)

# %%
arr = np.arange(10, 100, 10)
arr[-2]
# Out:
# 80
